# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('insurance_data.csv')
df.head()
# Out:
#    age  bought_insurance
# 0   22                 0
# 1   25                 0
# 2   47                 1
# 3   52                 0
# 4   46                 1

# %%
# %matplotlib inline
plt.xlabel('age')
plt.ylabel('bought_insurance')
plt.scatter(df.age, df.bought_insurance, marker = '+', color  = 'red')

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(df[['age']], df.bought_insurance, test_size = 0.1)

# %%
from sklearn.linear_model import LogisticsRegression
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 from sklearn.linear_model import LogisticsRegression
#
# ImportError: cannot import name 'LogisticsRegression' from 'sklearn.linear_model' (C:\Users\Deepak\Desktop\jupyter\env\Lib\site-packages\sklearn\linear_model\__init__.py)
