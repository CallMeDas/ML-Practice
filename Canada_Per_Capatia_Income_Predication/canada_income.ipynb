# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df = pd.read_csv('canada_per_capita_income.csv')
df.head(5)
# Out:
#    year  per capita income (US$)
# 0  1970              3399.299037
# 1  1971              3768.297935
# 2  1972              4251.175484
# 3  1973              4804.463248
# 4  1974              5576.514583

# %%
# %matplotlib inline

plt.xlabel('Year')
plt.ylabel('Per Capita Income')
plt.scatter(df.year, df['per capita income (US$)'])

# %%
model = linear_model.LinearRegression()
model.fit(df[['year']], df['per capita income (US$)'])
# Out:
# LinearRegression()

# %%
model.predict([[2020]])
# Out:
# C:\Users\Deepak\Desktop\jupyter\env\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([41288.69409442])

# %%
model.coef_
# Out:
# array([828.46507522])

# %%
model.intercept_
# Out:
# np.float64(-1632210.7578554575)

# %%
# %matplotlib inline
plt.xlabel('Year')
plt.ylabel('Income Per Capita')
plt.scatter(df['year'], df['per capita income (US$)'], color = 'red', marker = '*')
plt.plot(df['year'], model.predict(df[['year']]), color = 'green')
